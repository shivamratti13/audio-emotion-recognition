# %% [markdown]
# # Loading Liberaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv("Data/features.csv")

# %% [markdown]
# ### Summary

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452 entries, 0 to 2451
# Data columns (total 41 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0        2452 non-null   float64
#  1   1        2452 non-null   float64
#  2   2        2452 non-null   float64
#  3   3        2452 non-null   float64
#  4   4        2452 non-null   float64
#  5   5        2452 non-null   float64
#  6   6        2452 non-null   float64
#  7   7        2452 non-null   float64
#  8   8        2452 non-null   float64
#  9   9        2452 non-null   float64
#  10  10       2452 non-null   float64
#  11  11       2452 non-null   float64
#  12  12       2452 non-null   float64
#  13  13       2452 non-null   float64
#  14  14       2452 non-null   float64
#  15  15       2452 non-null   float64
#  16  16       2452 non-null   float64
#  17  17       2452 non-null   float64
#  18  18       2452 non-null   float64
#  19  19       2452 non-null   float64
#  20  20       2452 non-null   float64
#  21  21       2452 non-null   float64
#  22  22       2452 non-null   float64
#  23  23       2452 non-null   float64
#  24  24       2452 non-null   float64
#  25  25       2452 non-null   float64
#  26  26       2452 non-null   float64
#  27  27       2452 non-null   float64
#  28  28       2452 non-null   float64
#  29  29       2452 non-null   float64
#  30  30       2452 non-null   float64
#  31  31       2452 non-null   float64
#  32  32       2452 non-null   float64
#  33  33       2452 non-null   float64
#  34  34       2452 non-null   float64
#  35  35       2452 non-null   float64
#  36  36       2452 non-null   float64
#  37  37       2452 non-null   float64
#  38  38       2452 non-null   float64
#  39  39       2452 non-null   float64
#  40  emotion  2452 non-null   object
# dtypes: float64(40), object(1)
# memory usage: 785.5+ KB
# None

# %%
print(df['emotion'].value_counts())
# Out:
# emotion
# calm         376
# happy        376
# sad          376
# angry        376
# fearful      376
# disgust      192
# surprised    192
# neutral      188
# Name: count, dtype: int64

# %% [markdown]
# ### Visualize Emotion Distribution

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='emotion', data=df)
plt.title("Emotion Distribution")
plt.savefig("../emotion_distribution.png")
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include=[np.number])

plt.figure(figsize=(20,10))
corr = numeric_df.corr()
sns.heatmap(corr, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.savefig("../feature_correlation_heatmap.png")
plt.show()
